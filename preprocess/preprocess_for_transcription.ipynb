# %%
import json

# %%
def get_account_data(record):
    fields = []
    if "context" in record:
        for data in record["context"]:
            if data["system"] == "Salesforce":
                for object in data["objects"]:
                    if object["objectType"] in ["Account", "Opportunity"]:
                        fields.extend(object["fields"])
    return fields

# %%
def get_new_call(call):
    new_segments = []
    curr_segment = {}
    for segment in call['transcript']:
        segment_sents = [sent['text'] for sent in segment['sentences']]
        segment_start = segment['sentences'][0]['start']
        segment_end = segment['sentences'][-1]['end']
        if "speakerId" in curr_segment and segment['speakerId'] == curr_segment['speakerId']:
            curr_segment['sentences'] += segment_sents
            curr_segment['end'] = segment_end
            if segment['topic']:
                curr_segment['topics'].append(segment['topic'])
        else:
            if "sentences" in curr_segment and len(curr_segment['sentences']) > 0:
                new_segments.append(curr_segment)

            curr_segment = {
                "speakerId": segment['speakerId'],
                "speakerName": segment['speakerName'],
                "sentences": segment_sents,
                "start": segment_start,
                "end": segment_end,
                "topics": [],
            }
            if segment['topic']:
                curr_segment['topics'].append(segment['topic'])

    if "sentences" in curr_segment and len(curr_segment['sentences']) > 0:
        new_segments.append(curr_segment)

    affiliation_map = {party['speakerId']: party['affiliation'] for party in call['parties'] if party['speakerId']}
    name_map = {party['speakerId']: party['name'] for party in call['parties'] if party['speakerId']}

    output_segments = []
    # unknown_segments = []
    for i, curr_segment in enumerate(new_segments):
        if i > 0:
            prev_segment = new_segments[i-1]
            curr_segment['start'] = prev_segment['end']
        if i < len(new_segments) - 1:
            next_segment = new_segments[i+1]
            curr_segment['end'] += (next_segment['start'] - curr_segment['end']) / 2
        

    for new_segment in new_segments:
        if new_segment['speakerId'] in affiliation_map:
            # affiliation = affiliation_map[new_segment['speakerId']]
            # if affiliation not in ['Internal', 'External']:
            #     print("BAD AFFILIATION: ", new_segment)
            #     unknown_segments.append(new_segment)
            output_segment = {
                "speakerId": new_segment['speakerId'],
                "speakerName": name_map[new_segment['speakerId']],
                "speakerAffiliation": affiliation_map[new_segment['speakerId']],
                "topics": new_segment['topics'],
                "text": " ".join(new_segment['sentences']),
                "start": int(new_segment['start']),
                "end": int(new_segment['end'])
            }
            output_segments.append(output_segment)

    output_metadata = {
        "id": call['metaData']['id'],
        "title": call['metaData']['title'],
        "duration": call['metaData']['duration'],
    }

    output_call = {
        "metadata": output_metadata,
        "company_info": get_account_data(call),
        "segments": output_segments
    }

    return output_call

# %%
with open("/home/ubuntu/speech_to_text/data/intro.json", "r") as f:
    calls = json.load(f)

len(calls)
# Out:
# 428

# %%
new_calls = []
# all_unknown_segments = []
for call in calls:
    new_call = get_new_call(call)
    new_calls.append(new_call)
    # all_unknown_segments.extend(unknown_segments)

# %%
sum([len(call['segments']) for call in new_calls])
# Out:
# 37204

# %%
new_calls[0]
# Out:
# {'metadata': {'id': '956393886453945479',
#   'title': 'Saras | Hightouch <> Introductions',
#   'duration': 1419},
#  'company_info': [{'name': 'Industry',
#    'value': 'Internet Software & Services'},
#   {'name': 'Website', 'value': 'sarasanalytics.com'},
#   {'name': 'NumberOfEmployees', 'value': 150.0},
#   {'name': 'Name', 'value': 'Saras Analytics'},
#   {'name': 'Account_Level__c', 'value': 'COMM'}],
#  'segments': [{'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': 'Done.',
#    'start': 240,
#    'end': 1540},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': 'Hey, good evening, Ashraf. How you doing?',
#    'start': 1540,
#    'end': 3820},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': 'Yeah. All good, John morning. How are you doing?',
#    'start': 3820,
#    'end': 7060},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': "Good morning. I am just waking up on my first cup of coffee. So it's a Monday.",
#    'start': 7060,
#    'end': 13350},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': 'You starting your week?',
#    'start': 13350,
#    'end': 15325},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': "Sure. Something like that. Yeah. So no complaints here so far already second call the day… with some folks in Brazil as well. So we're going to international this morning, which is exciting.",
#    'start': 15325,
#    'end': 28835},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Call Setup'],
#    'text': 'Yeah. Glad to hear.',
#    'start': 28835,
#    'end': 31180},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Call Setup'],
#    'text': "Are you, you're in based in India, correct?",
#    'start': 31180,
#    'end': 33600},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Call Setup'],
#    'text': "Yeah. So, so this is like my tenth or twelfth out of the day. So it's been… yeah.",
#    'start': 33600,
#    'end': 42830},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Call Setup'],
#    'text': "I appreciate you making the time for me so late in the day. I'm honored.",
#    'start': 42830,
#    'end': 46540},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Call Setup'],
#    'text': "Yeah, no worries, John. So I've I just had my calendar so, you know, to have a go to overlap with the us teams because I primarily work with them. So, yeah, there's not.",
#    'start': 46540,
#    'end': 59230},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': 'This is normal for you. Okay. Good. Well, excellent. Well, good. Thanks for many time on a Monday. How was your weekend before we get into that?',
#    'start': 59230,
#    'end': 67700},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': "Yeah, good. I got some long time… you know, I've probably wanted it for a while but I got it unexpectedly. All the people I know have gone to some place together and I'm the one left behind. I spent it. Well.",
#    'start': 67700,
#    'end': 88490},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': 'Good for you. Just hanging out, keeping things mellow.',
#    'start': 88490,
#    'end': 92140},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': 'Yes. Yes. Just lying on the couch, you know, just roaming around alone. Yeah.',
#    'start': 92140,
#    'end': 97770},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk'],
#    'text': 'Sometimes you need weekends like that.',
#    'start': 97770,
#    'end': 101000},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Small Talk'],
#    'text': 'Yeah. Yeah. At least one of weekend. Yeah. How was yours?',
#    'start': 101000,
#    'end': 106020},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Small Talk', 'Call Setup'],
#    'text': "Mine was good. I, I'm not sure if you've been following the world cup at all, but I watched the France game on Saturday. I'm a decently big soccer football fan, whatever you wanna call. I played soccer in college… so I probably a bigger fan, the average American. So, yeah, I watched the France England game. That was a good time yesterday. I tried to spend as much time as possible on the couch so similar to you… trying to recharge before the new week. So, yeah, I think all good week on my side as well. So, thank you for asking.",
#    'start': 106020,
#    'end': 145080},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Call Setup'],
#    'text': 'Yeah, yeah, nice. Yeah.',
#    'start': 145080,
#    'end': 147950},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Call Setup'],
#    'text': "Love it. Well, we can definitely jump into things just by way of introduction. I'm John olderman, I'll be your main point of contact going forward certainly for the work with you in a VPN and most likely other accounts hopefully that we begin to partner on. So obviously I'm in the slack channel. I've been just catching up on everything that's been going on in that thread. I have your workspace pulled up. It's good to see as making some progress with syncing data from big query to Facebook being tick talk and Google ad. So that's exciting. So, yeah, I wanted to take this time keep pretty informal. I thought I'd be great to connect just one on one around the project and then we can talk about bringing in my technical team, your technical team and hopefully solve all the technical, you know, things you're trying to solve for. And then you and I can align on pricing everything like that down the line as well. So this little background my?",
#    'start': 147950,
#    'end': 204460},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Call Setup', 'Reverse ETL/Composable CDP', 'Ads'],
#    'text': "Yeah, yeah, sure. John. And let me introduce myself really quickly as well. I'm sure. You know, I'm an engagement manager with service analytics. We are an eCommerce focused, you know, analytics company. We work with 100 odd companies. I think anyone who's selling anything online, you know, we work with them, more or less, right? Basically. So you're working on the reverse ETL we are working on, you know, the conventional ETL, getting everything… all the data from different platforms into our warehouse and using that to provide visibility to provide insights to brands, right? So that's pretty much what we do. One of the brands that work with this VP. And I think this whole thing started because Krishna who's our CEO is friends with Heather. I think they might somewhere. Yeah. And she told me that this tool called Hightouch. And, you know, you can push data to add platforms and for BP, and we created this… customer table of customer 360 the way I like to call it, you know, creating segments, trying to push them to add platforms that's what we have used Hightouch for I don't know if the Facebook thing is working yet. I think we've been facing some issues for a while. So, Google Bing and I talk are working as expected. Facebook. I'm not sure we were facing some authentication issue. And then, you know, I think either you or someone else on the slack channel basically said that we had to at some permissions which I think we did. I'm not sure I got resolved.",
#    'start': 204460,
#    'end': 310900},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Call Setup'],
#    'text': "There's two John that you'll be working with, which is unfortunately is John Lois. He's my technical counterpart. Yeah, I did ping him about that exact issue. I know he did get back. So… now that, so I think John, on the technical side, he, he's working with a ton of different companies and projects. I think now that you know, as a part of the account team, I think we'll be more organized on our side going forward when it comes to support. Please, let us know in the slack channel how things are going. And I'll loop in John, my technical counterpart, John, our customer success team, I have access to as well. So, I think the combination of those two channels I think will be able to really help you guys going forward, which will be good.",
#    'start': 310900,
#    'end': 358660},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "Yeah. Yeah. Sure. John for BP specifically, right? I did mention them, there was a form that I think he shared the link for which is, you know, primarily connecting you to a PC from BPN, right? I did fill that form… and I gave a heads up to the BPN team as well that, you know, someone from your team will get in touch because I think they ran out of the trial period. So they should get on a paid plan soon enough and they like Hightouch and the value that it provides, but he was like you resolved the Facebook issue first, and then I'll get on a paid plan. Yeah, what?",
#    'start': 358660,
#    'end': 403420},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Sure. Sorry. So, Heather did send over some type of form.',
#    'start': 403420,
#    'end': 408000},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah. On the slack channel, I think there was some link that she asks us to fill and I did fill it.',
#    'start': 408000,
#    'end': 417435},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "Let's see. Maybe I'm just flying.",
#    'start': 417435,
#    'end': 436455},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Let me just check where.',
#    'start': 436455,
#    'end': 439670},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Or this lead referral form got?',
#    'start': 439670,
#    'end': 441930},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah. Yeah. So I did fill that. So you should have the contact details of the question from VPN to reach out to. So his name is Devon… is the one who manages the platform, is part of the marketing team at VPN. Yeah.',
#    'start': 441930,
#    'end': 462980},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Next Steps - POC & Testing'],
#    'text': "Okay. That's good to understand. So help me understand that more. So… when it comes to… now that I'm working with you guys, there's no like immediate rush to switch like let's technically validate this together and we'll work on pricing as well. It sounds like I'll be working with the VPN team directly in that respect when it comes to pricing or?",
#    'start': 462980,
#    'end': 488860},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "Yeah, I mean, yeah, I don't have, you know, the power to negotiate on their behalf or?",
#    'start': 488860,
#    'end': 494500},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'So.',
#    'start': 494500,
#    'end': 495485},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah. So I did.',
#    'start': 495485,
#    'end': 497710},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "Problem partnering partner. So that's good to know.",
#    'start': 497710,
#    'end': 501440},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "Yeah. So, yeah, we… yeah, I just like the, I pitched Hightouch directly myself and now they're interested and they should start paying so, and they should be paying to you, right? So it's better if you connect to them directly. I didn't give them a heads up that someone from Hightouch will get in touch. So, yeah. So that's fine. And yeah, once we resolve this issue, I think if we can figure out the price, they'll start to get on a plan.",
#    'start': 501440,
#    'end': 534500},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'That sounds great. Do they have some sort of defined budget they shared with you for?',
#    'start': 534500,
#    'end': 541180},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'No.',
#    'start': 541180,
#    'end': 542320},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "Okay. So I have to work with them on. Okay, that's good to know… we are making… to see what you guys are leveraging within the platform too.",
#    'start': 542320,
#    'end': 556020},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Reverse ETL/Composable CDP'],
#    'text': "Yeah. And yeah, I wanted to like touch base on that. I spoke to, I think the other John or I don't know who from your team trying to understand all the use cases, right? So even for B to make this, you know, to make Hightouch, you know, a stronger pitch for Hightouch, right? Either for VPN or for any other brand that we work with. The more we understand how to leverage Hightouch, it will make it easier for us to pitch. It's a win for everyone. It's a win for you. It's a win for them and it's a win for us. So… yeah. So I wanted to understand what all we can achieve for any commerce brand, what are the typical use cases that you've seen people trying to solve? Yeah, any understanding on that would be great.",
#    'start': 556020,
#    'end': 608530},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Call Setup'],
#    'text': "Yeah, 100 percent. I think just to start that conversation and I think it would be great to connect you directly with John for a little bit of a broader session just because… he's very familiar specifically… with the ad space, digital ad space per last company worked for which so I'm thinking on, but I'd say some of the high level things… before I just start talking about his. Do you know, obviously you guys are leveraging big query. Are you, how are you guys defining these tables in big query? Are you guys using DB T or are you just, you guys are leveraging?",
#    'start': 608530,
#    'end': 644780},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah, yeah. Yeah.',
#    'start': 644780,
#    'end': 646575},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Did you have you guys explored the DB T integration with Hightouch yet?',
#    'start': 646575,
#    'end': 651390},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Data Source'],
#    'text': "No, not yet. We are pushing data from big query right now. Yeah. So we didn't figure out, you know, perhaps the best practice of using these platforms. We just using BT, we created you know, table within big query and we created segments of customers and we are just pushing that from big query to Hightouch, right? So maybe there's a different way of doing it, but right now it's functional. So we're not worried about it.",
#    'start': 651390,
#    'end': 684160},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Modern Data Stack'],
#    'text': "Sure. Yeah. So I think there's a couple like just the highest level when it comes to Hightouch like the value props one similar like a Fivetran or whatever ETL tools you guys are leveraging on that side of your stack. Hightouch is going to bring that like managed scaleable infrastructure architecture that you're enjoying your stack. So when it comes to, you know, managing API, getting visibility into the quality of data that's passing from big query to all of these downstream systems, security… all the more like enterprise features under the hood that you would have to go and try to build that yourself. Hightouch has already been working on that for the last two and a half years and that's all we do, you know, or a purpose built architecture for sending data from data warehouse like big query, snowflake, you know, pick your data warehouse to these downstream systems. So all you have to worry about is okay, like let's focus on modeling really quality data customer, 360 tables like you're doing for VPN. Let's focus on that and making that as valuable as possible. We don't have to worry about all the plumbing in between. So we can just focus on like what are the actual direct outcomes we can get with this data from big query in these app platforms to maximize ad spend, to maximize subscriptions. I probably new do a little research on BP and myself to understand or the subscription based, you know, where can we really help them turn the needle? But I work with one of folks in the eCommerce space as well. So does John, so like there's a lot of like enterprise features that come along with Hightouch, like our D BT integration, the observe observability features. So you can see like, okay, what's like? Is this data actually coming going from point a to point B? If it's not, why is it failing? How much is failing? We also have our audiences platform which for your use cases might be very intriguing. I would, are you guys, have you done any research on the audience? This piece of our platform?",
#    'start': 684160,
#    'end': 812230},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "No, no, I mean, okay. So I think we did have a call with the other, John and yeah, he did walk us through a few use cases primarily. I think it is the same thing, right? Trying to segment customers using or from the data that we get in the warehouse, you're able to segment it and then push it to Hightouch, is the audiences piece. I think, right? While.",
#    'start': 812230,
#    'end': 841520},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Exactly.',
#    'start': 841520,
#    'end': 842360},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah.',
#    'start': 842360,
#    'end': 843380},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Customer Studio'],
#    'text': "So when you're doing segmentation for look at some of your use cases real quick. So when you're trying to look at like discount seekers, things like that, are you just building that in the warehouse and you make them like data marts or like TBT models there. And then you're pushing them downstream but they're defined that. Is that what it looks like? Yeah, got it. Okay. And when it comes to the requirements for this segmentation, does BPM, does their marketing team reach out to you directly and they say, hey, like here's, the types of segmentation we'd like to do, can you build this in the data warehouse to ship downstream? Is that basically the flow? Okay? So… we have that audience platform which allows instead of doing the segmentation solely in the data warehouse where, you know, it's gonna be yourself, whoever on your team is having to go in and actually manually do that. Hightouch allows you to do that segmentation downstream in the Hightouch platform through that no code interface. So say you want to empower the VPN team. So instead of having to go through your team every time they want to test out a new segmentation use case or tweak something on the models that are actually sending downstream, we have that no, no code interface. So the market is, instead of having to know SQL or like no DB T, now in Hightouch, they can just ask the question to ask, you know, give me all my customers that have these defined list of criteria and then they themselves can like be empowered to send those audiences downstream to all the platforms. So I'm not sure like… it's something that I'd say a lot of eCommerce customers find a lot of value from one just like the agility and speed that comes with it. If your marketing team, your marketing team in this case, being the BP and team, once you start doing experimentation, they want to do some AB testing on different… audience segments and they want to do it quickly. That's something that Hightouch allows.",
#    'start': 843380,
#    'end': 973840},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Yeah, yeah. Okay.',
#    'start': 973840,
#    'end': 976580},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "So that's is that something that's interesting or given your current model, do you think that's something that you probably wouldn't want to lever?",
#    'start': 976580,
#    'end': 983890},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "Depends. I mean, so I think the real value comes from the no code part… our team and I think even within BP and there are certain people who can write the code. So, yeah. So this is perhaps more convenient and they might end up using it, but I don't know if that will cause, you know, significant delta value for BP at the moment, right? So we…",
#    'start': 983890,
#    'end': 1014160},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Yeah.',
#    'start': 1014160,
#    'end': 1014900},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "The value currently that we're getting is, you know, pushing these segments, syncing them every day to each ad platform that's great, right? So this is an extra convenience on top of it, I feel… which is perhaps useful but, you know, not as impactful as the core use case. So, yeah.",
#    'start': 1014900,
#    'end': 1033720},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "For sure. Yeah. And we wanna like obviously crawl walk around. So we don't wanna like let's definitely solve this first. We're thinking about like long term, not just for VPN but other customers. I think the more complete understanding you have touch and everything that we can do when you're just putting the right solution in front of your customers, you'll be fully equipped to like have those conversations. So… so, yeah, I'd say… it sounds like you already had a chance to talk to John, so that's great as far as like more deep dives into like the use cases. I can send you an email that kind of has the like developer quality of life features if you want to call on that. Like all the things that like if you were trying to build this internally on your own, like you probably wouldn't have like the DB, an integration, get sync, integration, observability, things like that, if that would be helpful?",
#    'start': 1033720,
#    'end': 1093370},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': "Yeah, absolutely. So for VPN, I think the current use case is perhaps sufficient, right? And they see enough value to be, you know, perhaps willing to pay, right? Maybe for other brands that we work with. That is not the case and, you know, some other use case or value that you provide is going to be what, you know, they would prefer, right? So if you can, you know, share the email or whatever, right? Which can enable us enable me to understand, you know, what all we can achieve using Hightouch. And whenever the opportunity comes, we can pitch that and see, you know, if they're interested.",
#    'start': 1093370,
#    'end': 1133540},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': 'Is big query, your preferred data warehouse? Is that basically all your customers are on?',
#    'start': 1133540,
#    'end': 1139800},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'Not all customers, there are, some of them are in snowflake, some of them in something else, but yeah, the query is still preferred, you know? Yeah.',
#    'start': 1139800,
#    'end': 1150120},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': [],
#    'text': "Got it. Okay. That's helpful. I was just curious. I'm thinking about the resources send over.",
#    'start': 1150120,
#    'end': 1155515},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': [],
#    'text': 'So…',
#    'start': 1155515,
#    'end': 1157210},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Next Steps - POC & Testing', 'Destinations'],
#    'text': "Okay, great. I'd say, and this makes sense on the VPN side. So as far if I understand you correctly, like so far, so good. We, the Facebook piece is kind of the last hurdle and then it will be like fully live. And at that point, from a technical standpoint, feeling good about moving forward, correct? Yeah, sounds good. Are there any other alternatives? I only ask two questions. One, are they syncing this data from big query to these downstream systems today or is this like a net new project?",
#    'start': 1157210,
#    'end': 1193650},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Destinations'],
#    'text': "No. So we did set up these things… you know, to test it out, primarily, right? To see if this was working. And I think those things are happening right now as well. And VPN… what I've heard, right? Is they'd like to continue using high tech, which is great. They just wanted to understand, you know, the solution for the Facebook piece. Yeah. And then, you know, I think they're currently using it and they'll continue to use it in the next many months, but it requires a Facebook resolution and then maybe a conversation between your team and?",
#    'start': 1193650,
#    'end': 1238460},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Wrap-Up'],
#    'text': 'Got it. Okay. So that sounds great. I can, should I just reach out to them directly and ccu on that thread in terms of like…',
#    'start': 1238460,
#    'end': 1246810},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Wrap-Up'],
#    'text': 'Please?',
#    'start': 1246810,
#    'end': 1247840},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Wrap-Up', 'Next Steps - POC & Testing'],
#    'text': "Okay, perfect. I'll take that to do on that side. On the technical side… I think at this point, I know John got back. Let me see. Yeah. So it looks like John got back about the Facebook piece. Yeah, it looks like they accept the Facebook's terms conditions for custom audiences. And then they let us know if that works. If not… I can engage John or customers success team to make sure that gets ironed out appropriately. In the meantime, I'll send you an email to kinda documents some of the quality life features. So I have that in your back pocket. Is there anything else that myself and John can do for you? Like would it be helpful to have a demo to go through some of the more, I guess. So like the debt integration. If you haven't seen that in your leveraging debt, like for example, I think it would be helpful to see that, but like definitely like follow your lead on if, and when you like call with John to kinda walkthrough the platform?",
#    'start': 1247840,
#    'end': 1314915},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Next Steps - POC & Testing'],
#    'text': "No, I think we are good for now, John, we are able to use it, right for a future opportunity. Let us say if we need, you know, to integrate with BT, we can definitely reach out and you can arrange a demo and we can pitch it either to VPN or to someone else for that matter, right? So… yeah. So right now, I think we're good. If we resolve the Facebook please, I think we're good. I don't think unless there are the different use case, you say that, you know, BP can make extra dollars by using this feature or by pushing the data to some other platform, you know, that I, I'm sure the been team would also be pretty interested to learn about. But so far so good, I don't think there's any immediate next steps.",
#    'start': 1314915,
#    'end': 1363200},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Wrap-Up'],
#    'text': "Okay. Sounds good. Well, I'll go ahead and do all those actions as we talked about, I'll reach out to the PM team. I'll send you some of the quality life features, and then I'll make sure that we're all good on mechanical piece. Is there anything else question wise or anything else I can be doing for you in the meantime?",
#    'start': 1363200,
#    'end': 1378820},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Wrap-Up'],
#    'text': 'No, John, I think we would. Yeah.',
#    'start': 1378820,
#    'end': 1381910},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Wrap-Up'],
#    'text': "Fantastic. Well, I'll tell you what, thanks for making the time late on a Monday for you.",
#    'start': 1381910,
#    'end': 1387510},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Wrap-Up'],
#    'text': "No worries. Exactly. Yeah, thanks for taking all the time early Monday morning, your time, but yeah, nice talking to you, John. And yeah, I'll follow up with the between team once you shoot your email… and yeah, we can stay in touch going forward.",
#    'start': 1387510,
#    'end': 1405740},
#   {'speakerId': '8370954879572051754',
#    'speakerName': 'John Alderman',
#    'speakerAffiliation': 'Internal',
#    'topics': ['Wrap-Up'],
#    'text': "Fantastic. Well, it was great meeting you. Good start to my week. Hopefully it could end to your Monday or, and I'm sure you have more calls but yeah, we'll be in touch.",
#    'start': 1405740,
#    'end': 1414380},
#   {'speakerId': '1223525977315950398',
#    'speakerName': 'Ashraf',
#    'speakerAffiliation': 'External',
#    'topics': ['Wrap-Up'],
#    'text': 'Yeah, likewise is John, right? Right?',
#    'start': 1414380,
#    'end': 1417650}]}

# %%
with open("/home/ubuntu/speech_to_text/data/intro_calls_preprocessed_v2.json", "w") as f:
    json.dump(new_calls, f)

# %%
call_dir = "/home/ubuntu/speech_to_text/data/intro_calls_original"
for call in new_calls:
    with open(f"{call_dir}/{call['metadata']['id']}.json", "w") as f:
        json.dump(call, f)

# %%
durations = [call['metadata']['duration'] for call in new_calls][39:]

# %%
sum(durations) / len(durations)
# Out:
# 1662.7300771208227

# %%
len(durations)
# Out:
# 389

# %% [markdown]
# ### Run the below cells after retranscribing calls

# %%
with open("/home/ubuntu/speech_to_text/data/intro_calls_preprocessed_v2.json", "r") as f:
    intro_calls = json.load(f)

len(intro_calls)
# Out:
# 428

# %%
bad_call_ids = ["6781923412519057638"]
new_calls = []
for call in intro_calls:
    new_call_filename = f"/home/ubuntu/speech_to_text/data/intro_calls_retranscribed_v2/{call['metadata']['id']}.json"
    if os.path.exists(new_call_filename):
        with open(new_call_filename, "r") as f:
            new_call = json.load(f)
            if len(new_call['segments']) > 0 and call['metadata']['id'] not in bad_call_ids:
                new_calls.append(new_call)
            else:
                print(new_call['metadata']['id'])
    else:
        print(os.path.basename(new_call_filename))
# Out:
# 1765591959477928931
# 6781923412519057638
# 1088054306404649799.json
# 7635408987259473649.json

# %%
with open("/home/ubuntu/speech_to_text/data/intro_calls_retranscribed_v2.json", "w") as f:
    json.dump(new_calls, f)

len(new_calls)
# Out:
# 424
